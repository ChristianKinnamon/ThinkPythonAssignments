# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianKinnamon/ThinkPythonAssignments/blob/main/Week10/Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py

#Import Statements

# (None)

# Function Def

# 1) define add_players(roster)

# Use a While loop to let the player enter names

# Stop the loop when the user types quit

#  All names entered (except quit) should be added to the list

# 2) Define is_on_roster

# Returns True if the player is on the list

# Returns False if not

# Program Logic

# 1) create a list called "roster"

# 2) Call add_players to fil the list

# 3) Ask user for a specific name

# 4) Call is_on_roster

# 5) use the return value to print a message

def add_players(roster):
    while True:
          name = input("Enter player name(or 'quit' to stop): ")

          if name == "quit":
             break

          roster.append(name)

def is_on_roster(roster, player_name):
    if player_name in roster:
      return True
    else:
      return False

roster =[]

add_players(roster)

search_name = input("Who would you like to search for? ")

result = is_on_roster(roster, search_name)

if result:
   print("Result: Player found!")
else:
   print("Result: Player not found!")
# Out:
# Enter player name(or 'quit' to stop): bob
# Enter player name(or 'quit' to stop): quit
# Who would you like to search for? bob
# Result: Player found!
# ['bob']

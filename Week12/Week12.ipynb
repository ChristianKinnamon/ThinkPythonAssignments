# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianKinnamon/ThinkPythonAssignments/blob/main/Week12/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# (none)


# Function Definitions

# Define calculate_rectangle

# calculate area by multiplying length * width

# calculate perimeter using 2 * (length + width)

# pack values into a tuple

# return the tuple


# Program Logic

# Ask user to input a length and width

# Convert both inputs to float values

# Call calculate_rectangle() using user inputs

# Unpack returned tuple into my_area and my_perimeter

# Print results

def calculate_rectangle(length, width):
    area = length * width
    perimeter = 2 * (length + width)
    return (area, perimeter)

length = float(input("Enter Length: "))
width = float(input("Enter Width: "))
my_area, my_perimeter = calculate_rectangle(length, width)

print("--Results--")

print("The Area is:", my_area)

print("The Perimeter is:", my_perimeter)
# Out:
# Enter Length: 2
# Enter Width: 5
# --Results--
# The Area is: 10.0
# The Perimeter is: 14.0

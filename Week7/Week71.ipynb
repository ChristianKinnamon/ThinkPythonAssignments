# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianKinnamon/ThinkPythonAssignments/blob/main/Week7/Week71.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

#(None)


# Function Definitions

#  1) Define verify_pin()

# -Create a loop that asks for a PIN until it equals "1234"

# -Return True

# 2) Define withdraw(balance, amount):

# - Check if enough money exists

# - Return the new (or old) balance


# Program Logic

# 1) Set current_balance to 500

# 2) call verify_pin()

# 3) Get withdraw amount from user imput

# 4) Update current_balance by calling withdraw()

# 5) Print the final balance
